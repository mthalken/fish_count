# %%
# Import Dependancies
import pandas as pd
import numpy as np

import re

from sqlalchemy import create_engine
import psycopg2

from config import db_password

from path import Path

# %%
# Define data file directory
file_dir = '../Resources'

# %%
# Create total fish count DataFrame
fish_df = pd.read_csv(f'{file_dir}/total_data.csv', low_memory=False)
fish_df.head()
# Out:
#    Count_Id  Year  Month  Week_Number     Project       Date Chinook Run  \
# 0  19900315  1990      3           11  Bonneville  3/15/1990          Sp
# 1  19900316  1990      3           11  Bonneville  3/16/1990          Sp
# 2  19900317  1990      3           11  Bonneville  3/17/1990          Sp
# 3  19900318  1990      3           12  Bonneville  3/18/1990          Sp
# 4  19900319  1990      3           12  Bonneville  3/19/1990          Sp
#
#    Chin  JChin  Stlhd  WStlhd  Sock  Coho  JCoho  Shad  Lmpry  BTrout  Chum  \
# 0   2.0    NaN   27.0     NaN   NaN   NaN    NaN   NaN    NaN     NaN   NaN
# 1   1.0    NaN   44.0     NaN   NaN   NaN    NaN   NaN    NaN     NaN   NaN
# 2   2.0    NaN   36.0     NaN   NaN   NaN    NaN   NaN    NaN     NaN   NaN
# 3   1.0    NaN   60.0     NaN   NaN   NaN    NaN   NaN    NaN     NaN   NaN
# 4   NaN    NaN   46.0     NaN   NaN   NaN    NaN   NaN    NaN     NaN   NaN
#
#    Pink  TempC
# 0   NaN    6.7
# 1   NaN    7.2
# 2   NaN    6.7
# 3   NaN    7.2
# 4   NaN    7.8

# %%
# Convert TempC, Celcius values into TempF, Fahrenheit values
fish_df['TempF'] = fish_df['TempC'] * (9/5) + 32
fish_df.head()
# Out:
#    Count_Id  Year  Month  Week_Number     Project       Date Chinook Run  \
# 0  19900315  1990      3           11  Bonneville  3/15/1990          Sp
# 1  19900316  1990      3           11  Bonneville  3/16/1990          Sp
# 2  19900317  1990      3           11  Bonneville  3/17/1990          Sp
# 3  19900318  1990      3           12  Bonneville  3/18/1990          Sp
# 4  19900319  1990      3           12  Bonneville  3/19/1990          Sp
#
#    Chin  JChin  Stlhd  ...  Sock  Coho  JCoho  Shad  Lmpry  BTrout  Chum  \
# 0   2.0    NaN   27.0  ...   NaN   NaN    NaN   NaN    NaN     NaN   NaN
# 1   1.0    NaN   44.0  ...   NaN   NaN    NaN   NaN    NaN     NaN   NaN
# 2   2.0    NaN   36.0  ...   NaN   NaN    NaN   NaN    NaN     NaN   NaN
# 3   1.0    NaN   60.0  ...   NaN   NaN    NaN   NaN    NaN     NaN   NaN
# 4   NaN    NaN   46.0  ...   NaN   NaN    NaN   NaN    NaN     NaN   NaN
#
#    Pink  TempC  TempF
# 0   NaN    6.7  44.06
# 1   NaN    7.2  44.96
# 2   NaN    6.7  44.06
# 3   NaN    7.2  44.96
# 4   NaN    7.8  46.04
#
# [5 rows x 21 columns]

# %%
# Drop columns that are not used
fish_df.drop(['Chinook Run','Chin','JChin','WStlhd','Sock','Coho','JCoho','Shad','Lmpry','BTrout','Chum','Pink','TempC'], axis=1, inplace=True)
fish_df.head()
# Out:
#    Count_Id  Year  Month  Week_Number     Project       Date  Stlhd  TempF
# 0  19900315  1990      3           11  Bonneville  3/15/1990   27.0  44.06
# 1  19900316  1990      3           11  Bonneville  3/16/1990   44.0  44.96
# 2  19900317  1990      3           11  Bonneville  3/17/1990   36.0  44.06
# 3  19900318  1990      3           12  Bonneville  3/18/1990   60.0  44.96
# 4  19900319  1990      3           12  Bonneville  3/19/1990   46.0  46.04

# %%
# Create weather data DataFrame
weather_df = pd.read_csv(f'{file_dir}/bonWeather.csv', low_memory=False)
weather_df.head()
# Out:
#    Count_Id  Year  Month  Week_Number     Project      Date  \
# 0  19900101  1990      1            1  Bonneville  1/1/1990
# 1  19900102  1990      1            1  Bonneville  1/2/1990
# 2  19900103  1990      1            1  Bonneville  1/3/1990
# 3  19900104  1990      1            1  Bonneville  1/4/1990
# 4  19900105  1990      1            1  Bonneville  1/5/1990
#
#    TMAX (Degrees Fahrenheit)  TMIN (Degrees Fahrenheit)  PRCP (Inches)
# 0                       49.0                       35.0           0.89
# 1                       45.0                       36.0           0.85
# 2                       46.0                       39.0           0.02
# 3                       49.0                       42.0           0.04
# 4                       53.0                       45.0           0.47

# %%
# Define file path to save the steelhead fish count data
filepath = Path(f'{file_dir}/stlhd_count.csv')

# %%
# Save the steelhead data as a CSV file
fish_df.to_csv(filepath,index=False)

# %%
# Setting up the database connection
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/fish_count"
engine = create_engine(db_string)

# %%
# Read table combineddata from fish_count database
combined_df = pd.read_sql_table(table_name='combineddata', con=engine)
combined_df.head()
# Out:
#     countid yearvalue monthvalue weeknumber locationname daterecorded  \
# 0  19900101      1990          1          1   Bonneville   1990-01-01
# 1  19900102      1990          1          1   Bonneville   1990-01-02
# 2  19900103      1990          1          1   Bonneville   1990-01-03
# 3  19900104      1990          1          1   Bonneville   1990-01-04
# 4  19900105      1990          1          1   Bonneville   1990-01-05
#
#    maxtempf  mintempf  precipitationinch  watertempf  stlheadcount
# 0      49.0      35.0               0.89         NaN           NaN
# 1      45.0      36.0               0.85         NaN           NaN
# 2      46.0      39.0               0.02         NaN           NaN
# 3      49.0      42.0               0.04         NaN           NaN
# 4      53.0      45.0               0.47         NaN           NaN

# %%
# Define a file path to save the combined data file
filepath1 = Path(f'{file_dir}/combineddata.csv')

# %%
# Save the combined data as a CSV file
combined_df.to_csv(filepath1,index=False)
