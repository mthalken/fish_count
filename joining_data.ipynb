# %%
# Dependencies
import pandas as pd
import glob

# %%
# Create path to files, join, create df                            #https://stackoverflow.com/questions/20906474/import-multiple-csv-files-into-pandas-and-concatenate-into-one-dataframe
df = pd.concat(map(pd.read_csv, glob.glob('Resources/*.csv')))
df
# Out:
#                                               Project        Date Chinook Run  \
# 0                                          Bonneville  1990-03-15          Sp
# 1                                          Bonneville  1990-03-16          Sp
# 2                                          Bonneville  1990-03-17          Sp
# 3                                          Bonneville  1990-03-18          Sp
# 4                                          Bonneville  1990-03-19          Sp
# ..                                                ...         ...         ...
# 57  Steelhead Counts: The Steelhead parameter incl...         NaN         NaN
# 58  wild steelhead data was not published on a dai...         NaN         NaN
# 59  steelhead and may include unmarked hatchery fish.         NaN         NaN
# 60  Chinook Run Dates: Chinook runs (referring to ...         NaN         NaN
# 61  DART Data Citation. Columbia River DART, Colum...         NaN         NaN
#
#     Chin  JChin  Stlhd  WStlhd  Sock  Coho  JCoho  Shad  Lmpry  BTrout  Chum  \
# 0    2.0    NaN   27.0     NaN   NaN   NaN    NaN   NaN    NaN     NaN   NaN
# 1    1.0    NaN   44.0     NaN   NaN   NaN    NaN   NaN    NaN     NaN   NaN
# 2    2.0    NaN   36.0     NaN   NaN   NaN    NaN   NaN    NaN     NaN   NaN
# 3    1.0    NaN   60.0     NaN   NaN   NaN    NaN   NaN    NaN     NaN   NaN
# 4    NaN    NaN   46.0     NaN   NaN   NaN    NaN   NaN    NaN     NaN   NaN
# ..   ...    ...    ...     ...   ...   ...    ...   ...    ...     ...   ...
# 57   NaN    NaN    NaN     NaN   NaN   NaN    NaN   NaN    NaN     NaN   NaN
# 58   NaN    NaN    NaN     NaN   NaN   NaN    NaN   NaN    NaN     NaN   NaN
# 59   NaN    NaN    NaN     NaN   NaN   NaN    NaN   NaN    NaN     NaN   NaN
# 60   NaN    NaN    NaN     NaN   NaN   NaN    NaN   NaN    NaN     NaN   NaN
# 61   NaN    NaN    NaN     NaN   NaN   NaN    NaN   NaN    NaN     NaN   NaN
#
#     Pink  TempC
# 0    NaN    6.7
# 1    NaN    7.2
# 2    NaN    6.7
# 3    NaN    7.2
# 4    NaN    7.8
# ..   ...    ...
# 57   NaN    NaN
# 58   NaN    NaN
# 59   NaN    NaN
# 60   NaN    NaN
# 61   NaN    NaN
#
# [10901 rows x 16 columns]

# %%
df.to_csv('total_data.csv')
